# %%
from skgeom import minkowski

p1 = sg.Polygon([[0, 1], [0, -1], [1, 0], [-1,0]])
p2 = sg.Polygon([sg.Point2(3, -1), sg.Point2(5, -1), sg.Point2(5, 1), sg.Point2(3, 1)])

draw(p1, facecolor='red')
draw(p2, facecolor='blue')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-c48c91406994> in <module>
# ----> 1 from skgeom import minkowski
#       2
#       3 p1 = sg.Polygon([[0, 1], [0, -1], [1, 0], [-1,0]])
#       4 p2 = sg.Polygon([sg.Point2(3, -1), sg.Point2(5, -1), sg.Point2(5, 1), sg.Point2(3, 1)])
#       5
#
# ~/opt/anaconda3/lib/python3.8/site-packages/skgeom/__init__.py in <module>
#       1 # import all contents from C++ extension module
# ----> 2 from ._skgeom import *
#       3
#       4 from . import draw
#       5
#
# ImportError: dlopen(/Users/salman/opt/anaconda3/lib/python3.8/site-packages/skgeom/_skgeom.cpython-38-darwin.so, 2): Library not loaded: @rpath/libgmp.10.dylib
#   Referenced from: /Users/salman/opt/anaconda3/lib/python3.8/site-packages/skgeom/_skgeom.cpython-38-darwin.so
#   Reason: Incompatible library version: _skgeom.cpython-38-darwin.so requires version 15.0.0 or later, but libgmp.10.dylib provides version 14.0.0

# %%
result = minkowski.minkowski_sum(p1, p2)
draw(result)

# %%
conda install scikit-geometry -c conda-forge
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::_anaconda_depends==2021.11=py38_0
#   - defaults/osx-64::anaconda==custom=py38_1
#   - defaults/osx-64::scikit-learn-intelex==2021.4.0=py38hecd8cb5_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/salman/opt/anaconda3
#
#   added / updated specs:
#     - scikit-geometry
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boost-cpp-1.70.0           |       hd59e818_1        19.0 MB  conda-forge
#     ca-certificates-2021.10.8  |       h033912b_0         139 KB  conda-forge
#     certifi-2021.10.8          |   py38h50d1736_1         145 KB  conda-forge
#     cgal-cpp-5.0.1             |       hc4dabe3_0         5.7 MB  conda-forge
#     conda-4.11.0               |   py38h50d1736_0        16.9 MB  conda-forge
#     eigen-3.4.0                |       h940c156_0         1.2 MB  conda-forge
#     openssl-1.1.1l             |       h0d85af4_0         1.9 MB  conda-forge
#     scikit-geometry-0.1.2      |   py38hdca360a_2         2.5 MB  conda-forge
#     scikit-learn-0.24.2        |   py38hb2f4e1b_0         4.9 MB
#     ------------------------------------------------------------
#                                            Total:        52.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   boost-cpp          conda-forge/osx-64::boost-cpp-1.70.0-hd59e818_1
#   cgal-cpp           conda-forge/osx-64::cgal-cpp-5.0.1-hc4dabe3_0
#   eigen              conda-forge/osx-64::eigen-3.4.0-h940c156_0
#   scikit-geometry    conda-forge/osx-64::scikit-geometry-0.1.2-py38hdca360a_2
#   scikit-learn       pkgs/main/osx-64::scikit-learn-0.24.2-py38hb2f4e1b_0
#
# The following packages will be UPDATED:
#
#   certifi            pkgs/main::certifi-2021.10.8-py38hecd~ --> conda-forge::certifi-2021.10.8-py38h50d1736_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2021.10.26~ --> conda-forge::ca-certificates-2021.10.8-h033912b_0
#   conda              pkgs/main::conda-4.11.0-py38hecd8cb5_0 --> conda-forge::conda-4.11.0-py38h50d1736_0
#   openssl              pkgs/main::openssl-1.1.1l-h9ed2024_0 --> conda-forge::openssl-1.1.1l-h0d85af4_0
#
#
#
# Downloading and Extracting Packages
# cgal-cpp-5.0.1       | 5.7 MB    | ##################################### | 100%
# eigen-3.4.0          | 1.2 MB    | ##################################### | 100%
# scikit-geometry-0.1. | 2.5 MB    | ##################################### | 100%
# boost-cpp-1.70.0     | 19.0 MB   | ##################################### | 100%
# conda-4.11.0         | 16.9 MB   | ##################################### | 100%
# certifi-2021.10.8    | 145 KB    | ##################################### | 100%
# openssl-1.1.1l       | 1.9 MB    | ##################################### | 100%
# ca-certificates-2021 | 139 KB    | ##################################### | 100%
# scikit-learn-0.24.2  | 4.9 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: -
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install anaconda
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::anaconda==2020.11=py38_0
#   - defaults/osx-64::pywavelets==1.1.1=py38haf1e3a3_2
#   - defaults/osx-64::mkl_random==1.1.1=py38h959d312_0
#   - defaults/osx-64::scipy==1.5.2=py38h2515648_0
#   - defaults/osx-64::bottleneck==1.3.2=py38hf1fa96c_1
#   - defaults/osx-64::numpy==1.19.2=py38h456fd55_0
#   - defaults/osx-64::astropy==4.0.2=py38haf1e3a3_0
#   - defaults/noarch::imageio==2.9.0=py_0
#   - defaults/noarch::seaborn==0.11.0=py_0
#   - defaults/osx-64::patsy==0.5.1=py38_0
#   - defaults/osx-64::scikit-learn==0.23.2=py38h959d312_0
#   - defaults/osx-64::numexpr==2.7.1=py38hce01a72_0
#   - defaults/osx-64::scikit-image==0.17.2=py38h81aa140_0
#   - defaults/osx-64::tifffile==2020.10.1=py38h0cf3a3e_2
#   - defaults/osx-64::bokeh==2.2.3=py38_0
#   - defaults/osx-64::statsmodels==0.12.0=py38haf1e3a3_0
#   - defaults/noarch::dask==2.30.0=py_0
#   - defaults/osx-64::h5py==2.10.0=py38h3134771_0
#   - defaults/osx-64::matplotlib-base==3.3.2=py38h181983e_0
#   - defaults/osx-64::pandas==1.1.3=py38hb1e8313_0
#   - defaults/osx-64::bkcharts==0.2=py38_0
#   - defaults/osx-64::matplotlib==3.3.2=0
#   - defaults/osx-64::numba==0.51.2=py38h6440ff4_1
#   - defaults/osx-64::mkl_fft==1.2.0=py38hc64f4ea_0
#   - defaults/osx-64::pytables==3.6.1=py38h4727e94_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/salman/opt/anaconda3
#
#   added / updated specs:
#     - anaconda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2021.11  |           py38_0           7 KB
#     anaconda-custom            |           py38_1          35 KB
#     anyio-2.2.0                |   py38hecd8cb5_1         124 KB
#     arrow-0.13.1               |           py38_0          80 KB
#     binaryornot-0.4.4          |     pyhd3eb1b0_1         351 KB
#     black-19.10b0              |             py_0          86 KB
#     blosc-1.21.0               |       h2842e9f_0          49 KB
#     brotli-1.0.9               |       hb1e8313_2         398 KB
#     brunsli-0.1                |       h23ab428_0         142 KB
#     c-ares-1.17.1              |       h9ed2024_0          92 KB
#     ca-certificates-2021.10.26 |       hecd8cb5_2         115 KB
#     certifi-2021.10.8          |   py38hecd8cb5_0         151 KB
#     cfitsio-3.470              |       hee0f690_6         782 KB
#     charls-2.2.0               |       h23ab428_0          82 KB
#     charset-normalizer-2.0.4   |     pyhd3eb1b0_0          35 KB
#     conda-4.11.0               |   py38hecd8cb5_0        14.4 MB
#     conda-content-trust-0.1.1  |     pyhd3eb1b0_0          56 KB
#     conda-token-0.3.0          |     pyhd3eb1b0_0          10 KB
#     cookiecutter-1.7.2         |     pyhd3eb1b0_0          86 KB
#     daal4py-2021.4.0           |   py38h24a4e90_0         8.5 MB
#     dal-2021.4.0               |     hecd8cb5_689        61.2 MB
#     dataclasses-0.8            |     pyh6d0b6a4_7           8 KB
#     debugpy-1.5.1              |   py38he9d5cce_0         1.7 MB
#     flake8-3.9.2               |     pyhd3eb1b0_0         129 KB
#     fonttools-4.25.0           |     pyhd3eb1b0_0         632 KB
#     giflib-5.2.1               |       haf1e3a3_0          70 KB
#     imagecodecs-2021.8.26      |   py38ha952a84_0         5.8 MB
#     inflection-0.5.1           |   py38hecd8cb5_0          12 KB
#     intel-openmp-2021.4.0      |    hecd8cb5_3538         961 KB
#     jedi-0.18.0                |   py38hecd8cb5_0         906 KB
#     jinja2-time-0.2.0          |     pyhd3eb1b0_2          17 KB
#     jpeg-9d                    |       h9ed2024_0         215 KB
#     jupyter_server-1.4.1       |   py38hecd8cb5_0         313 KB
#     jupyterlab_widgets-1.0.0   |     pyhd3eb1b0_1         109 KB
#     jxrlib-1.1                 |       haf1e3a3_2         206 KB
#     lcms2-2.12                 |       hf1fd2bf_0         284 KB
#     lerc-3.0                   |       he9d5cce_0         168 KB
#     libaec-1.0.4               |       hb1e8313_1          26 KB
#     libcxx-12.0.0              |       h2f01273_0         805 KB
#     libdeflate-1.8             |       h9ed2024_5          50 KB
#     libev-4.33                 |       h9ed2024_1         106 KB
#     libllvm11-11.1.0           |       h9b2ccf5_0        17.7 MB
#     libnghttp2-1.46.0          |       ha29bfda_0         687 KB
#     libuv-1.40.0               |       haf1e3a3_0         334 KB
#     libwebp-1.2.0              |       hacca55c_0         441 KB
#     libwebp-base-1.2.0         |       h9ed2024_0         389 KB
#     libzopfli-1.0.3            |       hb1e8313_0         148 KB
#     lz4-c-1.9.3                |       h23ab428_1         140 KB
#     matplotlib-inline-0.1.2    |     pyhd3eb1b0_2          12 KB
#     mkl-2021.4.0               |     hecd8cb5_637       101.0 MB
#     mkl-service-2.4.0          |   py38h9ed2024_0          45 KB
#     mkl_fft-1.3.1              |   py38h4ab4a9b_0         165 KB
#     mkl_random-1.2.2           |   py38hb2f4e1b_0         273 KB
#     mpi-1.0                    |            mpich          13 KB
#     mpich-3.3.2                |       hc856adb_0         2.5 MB
#     munkres-1.1.4              |             py_0          13 KB
#     mypy_extensions-0.4.3      |           py38_0           9 KB
#     nbclassic-0.2.6            |     pyhd3eb1b0_0          19 KB
#     numexpr-2.7.3              |   py38h5873af2_1         124 KB
#     numpy-1.21.2               |   py38h4b4dc7a_0          23 KB
#     numpy-base-1.21.2          |   py38he0bd621_0         4.6 MB
#     openjpeg-2.4.0             |       h66ea3da_0         301 KB
#     openssl-1.1.1l             |       h9ed2024_0         2.2 MB
#     pathspec-0.7.0             |             py_0          26 KB
#     poyo-0.5.0                 |     pyhd3eb1b0_0          17 KB
#     pycodestyle-2.7.0          |     pyhd3eb1b0_0          41 KB
#     pyerfa-2.0.0               |   py38h9ed2024_0         358 KB
#     pyflakes-2.3.1             |     pyhd3eb1b0_0          60 KB
#     pyls-spyder-0.4.0          |     pyhd3eb1b0_0          11 KB
#     python-lsp-black-1.0.0     |     pyhd3eb1b0_0           8 KB
#     python-lsp-jsonrpc-1.0.0   |     pyhd3eb1b0_0          10 KB
#     python-lsp-server-1.2.4    |     pyhd3eb1b0_0          41 KB
#     python-slugify-5.0.2       |     pyhd3eb1b0_0          13 KB
#     qdarkstyle-3.0.2           |     pyhd3eb1b0_0         337 KB
#     qstylizer-0.1.10           |     pyhd3eb1b0_0          17 KB
#     qtawesome-1.0.3            |     pyhd3eb1b0_0         761 KB
#     qtconsole-5.1.1            |     pyhd3eb1b0_0          98 KB
#     rtree-0.9.7                |   py38hecd8cb5_1          48 KB
#     scikit-learn-intelex-2021.4.0|   py38hecd8cb5_0          66 KB
#     scipy-1.7.1                |   py38h88652d9_2        15.5 MB
#     snappy-1.1.8               |       hb1e8313_0          54 KB
#     sniffio-1.2.0              |   py38hecd8cb5_1          14 KB
#     spyder-5.1.5               |   py38hecd8cb5_1         9.3 MB
#     spyder-kernels-2.1.3       |   py38hecd8cb5_0         111 KB
#     tbb-2021.4.0               |       haf03e11_0         154 KB
#     tbb4py-2021.4.0            |   py38haf03e11_0          62 KB
#     text-unidecode-1.3         |     pyhd3eb1b0_0          65 KB
#     textdistance-4.2.1         |     pyhd3eb1b0_0          29 KB
#     three-merge-0.1.1          |     pyhd3eb1b0_0          10 KB
#     tinycss-0.4                |  pyhd3eb1b0_1002          39 KB
#     tornado-6.1                |   py38h9ed2024_0         585 KB
#     typed-ast-1.4.3            |   py38h9ed2024_1         180 KB
#     unidecode-1.2.0            |     pyhd3eb1b0_0         155 KB
#     whichcraft-0.6.1           |     pyhd3eb1b0_0          11 KB
#     zfp-0.5.5                  |       h23ab428_6         147 KB
#     zstd-1.4.9                 |       h322a384_0         476 KB
#     ------------------------------------------------------------
#                                            Total:       259.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/osx-64::_anaconda_depends-2021.11-py38_0
#   anyio              pkgs/main/osx-64::anyio-2.2.0-py38hecd8cb5_1
#   arrow              pkgs/main/osx-64::arrow-0.13.1-py38_0
#   binaryornot        pkgs/main/noarch::binaryornot-0.4.4-pyhd3eb1b0_1
#   black              pkgs/main/noarch::black-19.10b0-py_0
#   brotli             pkgs/main/osx-64::brotli-1.0.9-hb1e8313_2
#   brunsli            pkgs/main/osx-64::brunsli-0.1-h23ab428_0
#   c-ares             pkgs/main/osx-64::c-ares-1.17.1-h9ed2024_0
#   cfitsio            pkgs/main/osx-64::cfitsio-3.470-hee0f690_6
#   charls             pkgs/main/osx-64::charls-2.2.0-h23ab428_0
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   conda-content-tru~ pkgs/main/noarch::conda-content-trust-0.1.1-pyhd3eb1b0_0
#   conda-token        pkgs/main/noarch::conda-token-0.3.0-pyhd3eb1b0_0
#   cookiecutter       pkgs/main/noarch::cookiecutter-1.7.2-pyhd3eb1b0_0
#   daal4py            pkgs/main/osx-64::daal4py-2021.4.0-py38h24a4e90_0
#   dal                pkgs/main/osx-64::dal-2021.4.0-hecd8cb5_689
#   dataclasses        pkgs/main/noarch::dataclasses-0.8-pyh6d0b6a4_7
#   debugpy            pkgs/main/osx-64::debugpy-1.5.1-py38he9d5cce_0
#   fonttools          pkgs/main/noarch::fonttools-4.25.0-pyhd3eb1b0_0
#   giflib             pkgs/main/osx-64::giflib-5.2.1-haf1e3a3_0
#   imagecodecs        pkgs/main/osx-64::imagecodecs-2021.8.26-py38ha952a84_0
#   inflection         pkgs/main/osx-64::inflection-0.5.1-py38hecd8cb5_0
#   jinja2-time        pkgs/main/noarch::jinja2-time-0.2.0-pyhd3eb1b0_2
#   jupyter_server     pkgs/main/osx-64::jupyter_server-1.4.1-py38hecd8cb5_0
#   jupyterlab_widgets pkgs/main/noarch::jupyterlab_widgets-1.0.0-pyhd3eb1b0_1
#   jxrlib             pkgs/main/osx-64::jxrlib-1.1-haf1e3a3_2
#   lerc               pkgs/main/osx-64::lerc-3.0-he9d5cce_0
#   libaec             pkgs/main/osx-64::libaec-1.0.4-hb1e8313_1
#   libdeflate         pkgs/main/osx-64::libdeflate-1.8-h9ed2024_5
#   libev              pkgs/main/osx-64::libev-4.33-h9ed2024_1
#   libllvm11          pkgs/main/osx-64::libllvm11-11.1.0-h9b2ccf5_0
#   libnghttp2         pkgs/main/osx-64::libnghttp2-1.46.0-ha29bfda_0
#   libuv              pkgs/main/osx-64::libuv-1.40.0-haf1e3a3_0
#   libwebp            pkgs/main/osx-64::libwebp-1.2.0-hacca55c_0
#   libwebp-base       pkgs/main/osx-64::libwebp-base-1.2.0-h9ed2024_0
#   libzopfli          pkgs/main/osx-64::libzopfli-1.0.3-hb1e8313_0
#   matplotlib-inline  pkgs/main/noarch::matplotlib-inline-0.1.2-pyhd3eb1b0_2
#   mpi                pkgs/main/osx-64::mpi-1.0-mpich
#   mpich              pkgs/main/osx-64::mpich-3.3.2-hc856adb_0
#   munkres            pkgs/main/noarch::munkres-1.1.4-py_0
#   mypy_extensions    pkgs/main/osx-64::mypy_extensions-0.4.3-py38_0
#   nbclassic          pkgs/main/noarch::nbclassic-0.2.6-pyhd3eb1b0_0
#   numpy-base         pkgs/main/osx-64::numpy-base-1.21.2-py38he0bd621_0
#   openjpeg           pkgs/main/osx-64::openjpeg-2.4.0-h66ea3da_0
#   pathspec           pkgs/main/noarch::pathspec-0.7.0-py_0
#   poyo               pkgs/main/noarch::poyo-0.5.0-pyhd3eb1b0_0
#   pyerfa             pkgs/main/osx-64::pyerfa-2.0.0-py38h9ed2024_0
#   pyls-spyder        pkgs/main/noarch::pyls-spyder-0.4.0-pyhd3eb1b0_0
#   python-lsp-black   pkgs/main/noarch::python-lsp-black-1.0.0-pyhd3eb1b0_0
#   python-lsp-jsonrpc pkgs/main/noarch::python-lsp-jsonrpc-1.0.0-pyhd3eb1b0_0
#   python-lsp-server  pkgs/main/noarch::python-lsp-server-1.2.4-pyhd3eb1b0_0
#   python-slugify     pkgs/main/noarch::python-slugify-5.0.2-pyhd3eb1b0_0
#   qstylizer          pkgs/main/noarch::qstylizer-0.1.10-pyhd3eb1b0_0
#   scikit-learn-inte~ pkgs/main/osx-64::scikit-learn-intelex-2021.4.0-py38hecd8cb5_0
#   snappy             pkgs/main/osx-64::snappy-1.1.8-hb1e8313_0
#   sniffio            pkgs/main/osx-64::sniffio-1.2.0-py38hecd8cb5_1
#   tbb                pkgs/main/osx-64::tbb-2021.4.0-haf03e11_0
#   tbb4py             pkgs/main/osx-64::tbb4py-2021.4.0-py38haf03e11_0
#   text-unidecode     pkgs/main/noarch::text-unidecode-1.3-pyhd3eb1b0_0
#   textdistance       pkgs/main/noarch::textdistance-4.2.1-pyhd3eb1b0_0
#   three-merge        pkgs/main/noarch::three-merge-0.1.1-pyhd3eb1b0_0
#   tinycss            pkgs/main/noarch::tinycss-0.4-pyhd3eb1b0_1002
#   typed-ast          pkgs/main/osx-64::typed-ast-1.4.3-py38h9ed2024_1
#   unidecode          pkgs/main/noarch::unidecode-1.2.0-pyhd3eb1b0_0
#   whichcraft         pkgs/main/noarch::whichcraft-0.6.1-pyhd3eb1b0_0
#   zfp                pkgs/main/osx-64::zfp-0.5.5-h23ab428_6
#
# The following packages will be REMOVED:
#
#   python-language-server-0.35.1-py_0
#
# The following packages will be UPDATED:
#
#   blosc                                   1.20.1-hab81aa3_0 --> 1.21.0-h2842e9f_0
#   ca-certificates                              2020.10.14-0 --> 2021.10.26-hecd8cb5_2
#   certifi            pkgs/main/noarch::certifi-2020.6.20-p~ --> pkgs/main/osx-64::certifi-2021.10.8-py38hecd8cb5_0
#   conda                               4.10.1-py38hecd8cb5_1 --> 4.11.0-py38hecd8cb5_0
#   flake8                                         3.8.4-py_0 --> 3.9.2-pyhd3eb1b0_0
#   intel-openmp                                   2019.4-233 --> 2021.4.0-hecd8cb5_3538
#   jedi                                        0.17.1-py38_0 --> 0.18.0-py38hecd8cb5_0
#   jpeg                                        9b-he5867d9_2 --> 9d-h9ed2024_0
#   lcms2                                     2.11-h92f6f08_0 --> 2.12-hf1fd2bf_0
#   libcxx                                           10.0.0-1 --> 12.0.0-h2f01273_0
#   lz4-c                                    1.9.2-h79c402e_3 --> 1.9.3-h23ab428_1
#   mkl                                            2019.4-233 --> 2021.4.0-hecd8cb5_637
#   mkl-service                          2.3.0-py38hfbe908c_0 --> 2.4.0-py38h9ed2024_0
#   mkl_fft                              1.2.0-py38hc64f4ea_0 --> 1.3.1-py38h4ab4a9b_0
#   mkl_random                           1.1.1-py38h959d312_0 --> 1.2.2-py38hb2f4e1b_0
#   numexpr                              2.7.1-py38hce01a72_0 --> 2.7.3-py38h5873af2_1
#   numpy                               1.19.2-py38h456fd55_0 --> 1.21.2-py38h4b4dc7a_0
#   openssl                                 1.1.1h-haf1e3a3_0 --> 1.1.1l-h9ed2024_0
#   pycodestyle                                    2.6.0-py_0 --> 2.7.0-pyhd3eb1b0_0
#   pyflakes                                       2.2.0-py_0 --> 2.3.1-pyhd3eb1b0_0
#   qdarkstyle                                     2.8.1-py_0 --> 3.0.2-pyhd3eb1b0_0
#   qtawesome                                      1.0.1-py_0 --> 1.0.3-pyhd3eb1b0_0
#   qtconsole                                      4.7.7-py_0 --> 5.1.1-pyhd3eb1b0_0
#   rtree                                        0.9.4-py38_1 --> 0.9.7-py38hecd8cb5_1
#   scipy                                1.5.2-py38h2515648_0 --> 1.7.1-py38h88652d9_2
#   spyder                                       4.1.5-py38_0 --> 5.1.5-py38hecd8cb5_1
#   spyder-kernels                               1.9.4-py38_0 --> 2.1.3-py38hecd8cb5_0
#   tornado                              6.0.4-py38h1de35cc_1 --> 6.1-py38h9ed2024_0
#   zstd                                     1.4.5-h41d2c2f_0 --> 1.4.9-h322a384_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2020.11-py38_0 --> custom-py38_1
#
#
#
# Downloading and Extracting Packages
# blosc-1.21.0         | 49 KB     | ##################################### | 100%
# jedi-0.18.0          | 906 KB    | ##################################### | 100%
# mkl_fft-1.3.1        | 165 KB    | ##################################### | 100%
# textdistance-4.2.1   | 29 KB     | ##################################### | 100%
# mypy_extensions-0.4. | 9 KB      | ##################################### | 100%
# mkl-service-2.4.0    | 45 KB     | ##################################### | 100%
# rtree-0.9.7          | 48 KB     | ##################################### | 100%
# jxrlib-1.1           | 206 KB    | ##################################### | 100%
# intel-openmp-2021.4. | 961 KB    | ##################################### | 100%
# pathspec-0.7.0       | 26 KB     | ##################################### | 100%
# jupyterlab_widgets-1 | 109 KB    | ##################################### | 100%
# python-lsp-server-1. | 41 KB     | ##################################### | 100%
# pyerfa-2.0.0         | 358 KB    | ##################################### | 100%
# tbb-2021.4.0         | 154 KB    | ##################################### | 100%
# pyls-spyder-0.4.0    | 11 KB     | ##################################### | 100%
# fonttools-4.25.0     | 632 KB    | ##################################### | 100%
# numpy-1.21.2         | 23 KB     | ##################################### | 100%
# mpi-1.0              | 13 KB     | ##################################### | 100%
# matplotlib-inline-0. | 12 KB     | ##################################### | 100%
# typed-ast-1.4.3      | 180 KB    | ##################################### | 100%
# anyio-2.2.0          | 124 KB    | ##################################### | 100%
# tornado-6.1          | 585 KB    | ##################################### | 100%
# jupyter_server-1.4.1 | 313 KB    | ##################################### | 100%
# qtconsole-5.1.1      | 98 KB     | ##################################### | 100%
# debugpy-1.5.1        | 1.7 MB    | ##################################### | 100%
# cfitsio-3.470        | 782 KB    | ##################################### | 100%
# nbclassic-0.2.6      | 19 KB     | ##################################### | 100%
# numpy-base-1.21.2    | 4.6 MB    | ##################################### | 100%
# ca-certificates-2021 | 115 KB    | ##################################### | 100%
# daal4py-2021.4.0     | 8.5 MB    | ##################################### | 100%
# poyo-0.5.0           | 17 KB     | ##################################### | 100%
# whichcraft-0.6.1     | 11 KB     | ##################################### | 100%
# libwebp-1.2.0        | 441 KB    | ##################################### | 100%
# text-unidecode-1.3   | 65 KB     | ##################################### | 100%
# libzopfli-1.0.3      | 148 KB    | ##################################### | 100%
# certifi-2021.10.8    | 151 KB    | ##################################### | 100%
# cookiecutter-1.7.2   | 86 KB     | ##################################### | 100%
# munkres-1.1.4        | 13 KB     | ##################################### | 100%
# conda-token-0.3.0    | 10 KB     | ##################################### | 100%
# _anaconda_depends-20 | 7 KB      | ##################################### | 100%
# black-19.10b0        | 86 KB     | ##################################### | 100%
# mkl_random-1.2.2     | 273 KB    | ##################################### | 100%
# openssl-1.1.1l       | 2.2 MB    | ##################################### | 100%
# numexpr-2.7.3        | 124 KB    | ##################################### | 100%
# inflection-0.5.1     | 12 KB     | ##################################### | 100%
# charls-2.2.0         | 82 KB     | ##################################### | 100%
# three-merge-0.1.1    | 10 KB     | ##################################### | 100%
# spyder-kernels-2.1.3 | 111 KB    | ##################################### | 100%
# spyder-5.1.5         | 9.3 MB    | ##################################### | 100%
# lz4-c-1.9.3          | 140 KB    | ##################################### | 100%
# tbb4py-2021.4.0      | 62 KB     | ##################################### | 100%
# brunsli-0.1          | 142 KB    | ##################################### | 100%
# qstylizer-0.1.10     | 17 KB     | ##################################### | 100%
# pycodestyle-2.7.0    | 41 KB     | ##################################### | 100%
# mpich-3.3.2          | 2.5 MB    | ##################################### | 100%
# arrow-0.13.1         | 80 KB     | ##################################### | 100%
# libllvm11-11.1.0     | 17.7 MB   | ##################################### | 100%
# libwebp-base-1.2.0   | 389 KB    | ##################################### | 100%
# brotli-1.0.9         | 398 KB    | ##################################### | 100%
# mkl-2021.4.0         | 101.0 MB  | ##################################### | 100%
# snappy-1.1.8         | 54 KB     | ##################################### | 100%
# scikit-learn-intelex | 66 KB     | ##################################### | 100%
# libdeflate-1.8       | 50 KB     | ##################################### | 100%
# sniffio-1.2.0        | 14 KB     | ##################################### | 100%
# dataclasses-0.8      | 8 KB      | ##################################### | 100%
# zstd-1.4.9           | 476 KB    | ##################################### | 100%
# libev-4.33           | 106 KB    | ##################################### | 100%
# libnghttp2-1.46.0    | 687 KB    | ##################################### | 100%
# c-ares-1.17.1        | 92 KB     | ##################################### | 100%
# imagecodecs-2021.8.2 | 5.8 MB    | ##################################### | 100%
# qdarkstyle-3.0.2     | 337 KB    | ##################################### | 100%
# unidecode-1.2.0      | 155 KB    | ##################################### | 100%
# qtawesome-1.0.3      | 761 KB    | ##################################### | 100%
# flake8-3.9.2         | 129 KB    | ##################################### | 100%
# conda-4.11.0         | 14.4 MB   | ##################################### | 100%
# libcxx-12.0.0        | 805 KB    | ##################################### | 100%
# tinycss-0.4          | 39 KB     | ##################################### | 100%
# python-lsp-jsonrpc-1 | 10 KB     | ##################################### | 100%
# pyflakes-2.3.1       | 60 KB     | ##################################### | 100%
# giflib-5.2.1         | 70 KB     | ##################################### | 100%
# zfp-0.5.5            | 147 KB    | ##################################### | 100%
# libaec-1.0.4         | 26 KB     | ##################################### | 100%
# lcms2-2.12           | 284 KB    | ##################################### | 100%
# jinja2-time-0.2.0    | 17 KB     | ##################################### | 100%
# conda-content-trust- | 56 KB     | ##################################### | 100%
# charset-normalizer-2 | 35 KB     | ##################################### | 100%
# binaryornot-0.4.4    | 351 KB    | ##################################### | 100%
# libuv-1.40.0         | 334 KB    | ##################################### | 100%
# dal-2021.4.0         | 61.2 MB   | ##################################### | 100%
# python-lsp-black-1.0 | 8 KB      | ##################################### | 100%
# python-slugify-5.0.2 | 13 KB     | ##################################### | 100%
# jpeg-9d              | 215 KB    | ##################################### | 100%
# openjpeg-2.4.0       | 301 KB    | ##################################### | 100%
# lerc-3.0             | 168 KB    | ##################################### | 100%
# scipy-1.7.1          | 15.5 MB   | ##################################### | 100%
# anaconda-custom      | 35 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge dlib
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/salman/opt/anaconda3
#
#   added / updated specs:
#     - dlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     dlib-19.22.0               |   py38hf565bbc_0         3.7 MB  conda-forge
#     libblas-3.9.0              |     12_osx64_mkl          12 KB  conda-forge
#     libcblas-3.9.0             |     12_osx64_mkl          12 KB  conda-forge
#     liblapack-3.9.0            |     12_osx64_mkl          12 KB  conda-forge
#     sqlite-3.36.0              |       hce871da_0         1.1 MB
#     ------------------------------------------------------------
#                                            Total:         4.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   dlib               conda-forge/osx-64::dlib-19.22.0-py38hf565bbc_0
#   libblas            conda-forge/osx-64::libblas-3.9.0-12_osx64_mkl
#   libcblas           conda-forge/osx-64::libcblas-3.9.0-12_osx64_mkl
#   liblapack          conda-forge/osx-64::liblapack-3.9.0-12_osx64_mkl
#
# The following packages will be UPDATED:
#
#   sqlite                                  3.33.0-hffcf06c_0 --> 3.36.0-hce871da_0
#
#
#
# Downloading and Extracting Packages
# dlib-19.22.0         | 3.7 MB    | ##################################### | 100%
# liblapack-3.9.0      | 12 KB     | ##################################### | 100%
# sqlite-3.36.0        | 1.1 MB    | ##################################### | 100%
# libcblas-3.9.0       | 12 KB     | ##################################### | 100%
# libblas-3.9.0        | 12 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
brew reinstall shellcheck
# Out:
#   File "<ipython-input-5-102d6d2c11f8>", line 1
#     brew reinstall shellcheck
#          ^
# SyntaxError: invalid syntax
